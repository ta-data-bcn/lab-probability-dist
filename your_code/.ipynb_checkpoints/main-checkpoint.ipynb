# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# Import your libraries
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
from math import sqrt

# %% [markdown]
# # Challenge 1 - Generate and Plot Normal Distributions

# %% [markdown]
# #### Step 1: Generate samples and test normal distribution
#
# Use mean=50, standard_deviation=5, and sample_size=[10, 50, 500, 5000] to generate 4 random samples that are normally distributed. Test your normal distributions with [`scipy.stats.normaltest`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.normaltest.html).
#
#
# *Hint: Read the documentation for `scipy.stats.normaltest`. The function does not simply return Yes or No for whether your data is normal distribution. It returns the likelihood.*

# %%
# Your code here
n1 = np.random.normal(loc=50, scale=5, size=10)
n2 = np.random.normal(loc=50, scale=5, size=50)
n3 = np.random.normal(loc=50, scale=5, size=500)
n4 = np.random.normal(loc=50, scale=5, size=1000)

print(stats.normaltest(n1))
print(stats.normaltest(n2))
print(stats.normaltest(n3))
print(stats.normaltest(n4))
# Out:
# NormaltestResult(statistic=1.6586538492964098, pvalue=0.4363428791422881)
# NormaltestResult(statistic=2.279703402245926, pvalue=0.3198664541350872)
# NormaltestResult(statistic=1.299803584772071, pvalue=0.522097048148711)
# NormaltestResult(statistic=0.24824881071670693, pvalue=0.8832699505326995)

# %% [markdown]
# #### Interpret the normaltest results and make your observations.

# %%
# Explain the test results here

# if pvalue is under 0.05 (with 95% confidence interval) we can reject the null hipotesis, so it is normally distributed

# %% [markdown]
# #### Step 2: Plot normal distributions
#
# Use matplotlib to plot a histogram of each sample.
#
# *Hints:*
#
# - Your outputs should look like below:
#
# ![normal distributions with different sample sizes](ch-1.png)

# %%
plt.hist(n1)
plt.title('n = 10')
plt.show()

# %%
plt.hist(n2)
plt.title('n = 50')
plt.show()

# %%
plt.hist(n3)
plt.title('n = 500')
plt.show()

# %%
plt.hist(n4)
plt.title('n = 1000')
plt.show()

# %% [markdown]
# #### Compare the distributions above. What do you observe? Explain with the Central Limit Theorem.

# %%
# Your comment and explanation here

# %% [markdown]
# # Challenge 2 - Plot Probability Mass Function (PMF)

# %% [markdown]
# #### Background knowledge
#
# [PF](https://en.wikipedia.org/wiki/Probability_mass_function) shows the probability distribution of a **discrete random variable**. A [discrete random variable](https://en.wikipedia.org/wiki/Random_variable#Discrete_random_variable) has random numeric values that are not continuous. For example, the number of people in a household can only be integers but not floats. Therefore the number of people in a household is a discrete variable.
#
# #### Question: We assume that the probability of clicking an Ad in a Youtube video is 0.15. We have a sample of 5 people who wathched the video and we want to plot the PMF for a binomial distribution.
#
# *Hint: use binom from `scipy.stats.binom`. Your output should look like below:*
#
# ![binom 10](ch-2.png)

# %%
x = range(6)
plt.plot(stats.binom.pmf(x, 5, 0.15))
plt.show()

# %% [markdown]
# #### Explain what you observe from the plot above

# %% [markdown]
# #### Now plot PMP with 50, 500, and 5000 visitors.

# %%
plt.plot(stats.binom.pmf(range(50), 50, 0.15))
plt.show()

# %%
plt.plot(stats.binom.pmf(range(500), 500, 0.15))
plt.show()

# %%
plt.plot(stats.binom.pmf(range(5000), 5000, 0.15))
plt.show()

# %% [markdown]
# #### What did you notice from the distribution plots? Comment your findings.

# %%
# Your comment here

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Reaserch the Poisson distribution. Write about your own understanding of the Poisson distribution.

# %%
# Your comment here

# %% [markdown]
# #### A website has an average of 300 visits per day. What is the probability of getting 320 visitors in a day?
#
# *Hint: use `scipy.stats.poisson`*

# %%
# Your code here
stats.poisson.pmf(320,300)
# Out:
# 0.011612348610402475

# %% [markdown]
# #### What is the probability of getting 60 visits?

# %%
# Your code here
stats.poisson.pmf(60,300)
# Out:
# 2.622743762294515e-64

# %% [markdown]
# #### Plot the distribution of the probability for getting 0-1000 visits.
#
# *Hints:*
#
# - Create a list to store the Poisson distribution probabilities for n=0 to 1000. Then plot the probabilities.
#
# - Your plot should look like below:
#
# ![poisson distribution](ch-3.png)

# %%
# your code here
plt.plot(stats.poisson.pmf(range(1001),300))
plt.show()

# %% [markdown]
# # Challenge 4 - Central Limit Theorem

# %% [markdown]
# #### Example of application
#
# A delivery company needs 35 minutes to deliver a package, with a standard deviation of 8 minutes. Suppose that in one day, they deliver 200 packages.
#
# #### a. What is the probability that the mean delivery time today is between 30 and 35 minutes?

# %%
plt.plot(stats.norm.pdf(range(100), 35, 8/sqrt(200)))
plt.show()

print(0.5 - stats.norm.cdf(30, 35, 8/sqrt(200)))
# Out:
# 0.5

# %% [markdown]
# #### b. What is the probablity that in total, it takes more than 115 hours to deliver all 200 packages?
